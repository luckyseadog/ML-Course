# %% [markdown]
# # SVM и его ядра
# __Суммарное количество баллов: 10__

# %% [markdown]
# В этом задании вам не нужно будет реализовать SVM, а научиться его применять.

# %% [markdown]
# Примените метод SVM (например, из библиотеки sklearn) для датасета blobs2.
#
# Визуализируйте результат (разбиение плоскости и опорные вектора) при разных вариантах ядер (линейное; полиномиальное степеней 2,3,5; RBF).

# %%
from sklearn.svm import SVC 
from sklearn.datasets import make_blobs

X_blobs2, y_blobs2  = make_blobs(n_samples=1000, random_state=4, center_box=(-2, 2),cluster_std=0.4, centers=2)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


clf = SVC(kernel = 'poly', degree = 2)
clf.fit(X_blobs2, y_blobs2)
clf.support_vectors_
plt.scatter(pd.DataFrame(X_blobs2).iloc[:, 0], pd.DataFrame(X_blobs2).iloc[:, 1], c=y_blobs2, s=50, cmap='autumn')


ax = plt.gca()

xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)


xy = np.vstack([XX.ravel(), YY.ravel()]).T



Z = clf.decision_function(xy).reshape(XX.shape)

ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])


plt.show()

# %%
clf = SVC(kernel = 'poly', degree = 3)
clf.fit(X_blobs2, y_blobs2)
clf.support_vectors_
plt.scatter(pd.DataFrame(X_blobs2).iloc[:, 0], pd.DataFrame(X_blobs2).iloc[:, 1], c=y_blobs2, s=50, cmap='autumn')


ax = plt.gca()

xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)



#print(np.vstack([XX.ravel(), YY.ravel()]))
xy = np.vstack([XX.ravel(), YY.ravel()]).T



Z = clf.decision_function(xy).reshape(XX.shape)

ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])


plt.show()

# %%
clf = SVC(kernel = 'poly', degree = 5)
clf.fit(X_blobs2, y_blobs2)
clf.support_vectors_
plt.scatter(pd.DataFrame(X_blobs2).iloc[:, 0], pd.DataFrame(X_blobs2).iloc[:, 1], c=y_blobs2, s=50, cmap='autumn')

ax = plt.gca()

xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)



xy = np.vstack([XX.ravel(), YY.ravel()]).T



Z = clf.decision_function(xy).reshape(XX.shape)

ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])


plt.show()

# %%
clf = SVC(kernel = 'rbf')
clf.fit(X_blobs2, y_blobs2)
clf.support_vectors_
plt.scatter(pd.DataFrame(X_blobs2).iloc[:, 0], pd.DataFrame(X_blobs2).iloc[:, 1], c=y_blobs2, s=50, cmap='autumn')

ax = plt.gca()

xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)



xy = np.vstack([XX.ravel(), YY.ravel()]).T



Z = clf.decision_function(xy).reshape(XX.shape)

ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])


plt.show()

# %%
clf = SVC(kernel = 'linear')
clf.fit(X_blobs2, y_blobs2)
clf.support_vectors_
plt.scatter(pd.DataFrame(X_blobs2).iloc[:, 0], pd.DataFrame(X_blobs2).iloc[:, 1], c=y_blobs2, s=50, cmap='autumn')
#plt.scatter(clf.support_vectors_[:,0],clf.support_vectors_[:,1])

ax = plt.gca()

xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)



xy = np.vstack([XX.ravel(), YY.ravel()]).T



Z = clf.decision_function(xy).reshape(XX.shape)

ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])


plt.show()

# %% [markdown]
# Протестируйте SVM на датасете spam. Для этой задачи используйте данные x_spam_train и y_spam_train:
#
# 1. Выполните загрузку и предобработку файлов x_spam_train и y_spam_train.
# 2. Разбейте x_spam_train и y_spam_train на x_train, y_train, x_test и y_test для оценки точности работы алгоритма.
# 3. Посчитайте метрики precision, recall, accuracy для модели SVM. Если необходимо, попробуйте разные наборы параметров для получения лучшего результата.
# 4. Сравните время работы SVM и Random Forest при близкой точности.
#
# Ответьте на следующие вопросы:
# 1. Какой нужен препроцессинг данных для моделей?
# 2. Какая модель делает предсказания лучше? Предположите, почему.

# %%
from sklearn.model_selection import train_test_split

def pure(X):
    x_copy = X.copy()
    if 'Id' in x_copy.columns:
        del x_copy['Id']
    if 'y' in x_copy.columns:
        del x_copy['y']
    return x_copy


DATA_PATH_X = '../input/homework-svm/x_spam_train.csv'
DATA_PATH_Y = '../input/homework-svm/y_spam_train.csv'
DATA_PATH_X_test = '../input/homework-svm/x_spam_test.csv'

x_spam_train = pd.read_csv(DATA_PATH_X)
y_spam_train = pd.read_csv(DATA_PATH_Y)
x_spam_test = pd.read_csv(DATA_PATH_X_test)



x_train, x_test, y_train, y_test = train_test_split(x_spam_train, y_spam_train, test_size=0.3, random_state = 42)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score
from sklearn.ensemble import RandomForestClassifier
import time

t0 = time.perf_counter()
ver1 = RandomForestClassifier()
ver1.fit(pure(x_train), pure(y_train))
pred1 = ver1.predict(pure(x_test))
print('accuracy :', accuracy_score(pure(y_test), pred1))
print('recall_score :', recall_score(pure(y_test), pred1))
print('precision_score :', precision_score(pure(y_test), pred1))
t1 = time.perf_counter()
print('time forest :', t1 - t0)

t2 = time.perf_counter()
ver2 = SVC(kernel = 'linear')
ver2.fit(pure(x_train), pure(y_train))
pred2 = ver2.predict(pure(x_test))
print('accuracy :', accuracy_score(pure(y_test), pred2))
print('recall_score :', recall_score(pure(y_test), pred2))
print('precision_score :', precision_score(pure(y_test), pred2))
t3 = time.perf_counter()
print('time SVC:', t3 - t2)

# %% [markdown]
# Обучите модель на всех данных из x_spam_train и y_spam_train.
# Сделайте submit своего решения и получите значение f1_score не менее 0.6

# %%
submission = pd.DataFrame(columns = ["Id", "Expected"])
submission["Id"] = x_spam_test["Id"]
submission["Expected"] = ver2.predict(pure(x_spam_test))
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# Random Forest делает предсказания лучше и быстрее.
